# %% [markdown]
# ### Why data visualization?
# - Gain insight into an information space by mapping data onto graphical primitives
#
# - Provide qualitative overview of large data sets
#
# - Search for patterns, trends, structure, irregularities, relationships among data
#
# - Help find interesting regions and suitable parameters for further quantitative analysis
#
# - Provide a visual proof of computer representations derived

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
df_all = pd.read_csv("C:/Users/sasiv/Documents/GitHub/MachineLearning/EX1_pandas/EX1_pandas/data/data.csv")

df_all.head(5)
# Out:
#        awayX      awayY  bullseyeX  bullseyeY    circleX    circleY    dinoX  \
# 0  32.331110  61.411101  51.203891  83.339777  55.993030  79.277264  55.3846
# 1  53.421463  26.186880  58.974470  85.499818  50.032254  79.013071  51.5385
# 2  63.920202  30.832194  51.872073  85.829738  51.288459  82.435940  46.1538
# 3  70.289506  82.533649  48.179931  85.045117  51.170537  79.165294  42.8205
# 4  34.118830  45.734551  41.683200  84.017941  44.377915  78.164628  40.7692
#
#      dinoY      dotsX      dotsY  ...  high_linesX  high_linesY  slant_downX  \
# 0  97.1795  51.147917  90.867412  ...    57.613234    83.905171    52.872021
# 1  96.0256  50.517126  89.102395  ...    51.274392    82.817983    59.014144
# 2  94.4872  50.207480  85.460047  ...    50.753898    76.754129    56.375109
# 3  91.4103  50.069482  83.057670  ...    37.021184    81.954470    37.839200
# 4  88.3333  50.562846  82.937822  ...    42.881755    80.184770    39.885373
#
# ...

# %%
df_all.describe()
# Out:
#             awayX       awayY   bullseyeX   bullseyeY     circleX     circleY  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    54.266100   47.834721   54.268730   47.830823   54.267320   47.837717
# std     16.769825   26.939743   16.769239   26.935727   16.760013   26.930036
# min     15.560750    0.015119   19.288205    9.691547   21.863581   16.326546
# 25%     39.724115   24.625892   41.627968   26.244735   43.379116   18.349610
# 50%     53.340296   47.535269   53.842088   47.382937   54.023213   51.025022
# 75%     69.146597   71.803148   64.798900   72.532852   64.972672   77.782382
# max     91.639961   97.475771   91.735539   85.876229   85.664761   85.578134
#
#             dinoX       dinoY       dotsX       dotsY  ...  high_linesX  \
# count  142.000000  142.000000  142.000000  142.000000  ...   142.000000
# mean    54.263273   47.832253   54.260303   47.839829  ...    54.268805
# ...

# %%
df = df_all[['bullseyeX', 'bullseyeY', 'circleX', 'circleY', 'starX', 'starY', 'dinoX', 'dinoY']]
df.head()
# Out:
#    bullseyeX  bullseyeY    circleX    circleY      starX      starY    dinoX  \
# 0  51.203891  83.339777  55.993030  79.277264  58.213608  91.881892  55.3846
# 1  58.974470  85.499818  50.032254  79.013071  58.196054  92.214989  51.5385
# 2  51.872073  85.829738  51.288459  82.435940  58.718231  90.310532  46.1538
# 3  48.179931  85.045117  51.170537  79.165294  57.278373  89.907607  42.8205
# 4  41.683200  84.017941  44.377915  78.164628  58.082020  92.008145  40.7692
#
#      dinoY
# 0  97.1795
# 1  96.0256
# 2  94.4872
# 3  91.4103
# 4  88.3333

# %%
fig, ((ax1, ax2)) = plt.subplots(1, 2, sharey = True)

ax1.boxplot([df['bullseyeX'], df['circleX'], df['starX'], df['dinoX']])
ax2.boxplot([df['bullseyeY'], df['circleY'], df['starY'], df['dinoY']])

fig.suptitle('Box plots')
ax1.set_title('X boxplots')
ax2.set_title('Y boxplots')

plt.show()

# %% [markdown]
# ### Another way to make subplots

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

fig.suptitle('Box plots')
ax1.set_title('X boxplots')
ax2.set_title('Y boxplots')

ax1.boxplot([df['bullseyeX'], df['circleX'], df['starX'], df['dinoX']])
ax2.boxplot([df['bullseyeY'], df['circleY'], df['starY'], df['dinoY']])

plt.show()

# %%
fig, ((ax1, ax2, ax3, ax4), 
      (ay1, ay2, ay3, ay4)) = plt.subplots(2, 4, figsize = [8, 6], 
                                           sharey=True, sharex=True)

ax1.hist(df['bullseyeX'])
ax2.hist(df['circleX'])
ax3.hist(df['starX'])
ax4.hist(df['dinoX'])

ay1.hist(df['bullseyeY'])
ay2.hist(df['circleY'])
ay3.hist(df['starY'])
ay4.hist(df['dinoY'])

fig.suptitle('Histotrams')

plt.show()

# %%
fig, ((a1, a2), (a3, a4)) = plt.subplots(2, 2, figsize = [8, 8],
                                        sharex=True, sharey=True)

a1.scatter(df['bullseyeX'], df['bullseyeY'])
a2.scatter(df['circleX'], df['circleY'])
a3.scatter(df['starX'], df['starY'])
a4.scatter(df['dinoX'], df['dinoY'])

a1.set_ylabel('Y')
a3.set_xlabel('X')
a3.set_ylabel('Y')
a4.set_xlabel('X')

fig.suptitle('Scatter plots')

plt.show()

# %% [markdown]
# ### find coefficient correlation factor between x and y

# %%
print("Bullseye:", df['bullseyeX'].corr(df['bullseyeY']))
print("Circle:", df['circleX'].corr(df['circleY']))
print("Star:", df['starX'].corr(df['starY']))
print("Dino:", df['dinoX'].corr(df['dinoY']))
# Out:
# Bullseye: -0.0685863942410766
# Circle: -0.06834335648025565
# Star: -0.06296110022065424
# Dino: -0.06447185270095165
